# %%
import sqlite3
import csv

# %%
import pandas as pd

# %%
date = pd.read_csv("/Users/ndias/SQL with Python/sql_with_python/Calculator for Investors/financial.csv")

# %%
date
# Out:
#    ticker        ebitda         sales    net_profit   market_price  \
# 0    AAPL  1.307950e+11  3.658170e+11  9.468000e+10  2279000000000
# 1    MSFT  9.576900e+10  1.680880e+11  6.127100e+10  1900000000000
# 2    GOOG  9.530500e+10  2.574880e+11  7.603300e+10  1479000000000
# 3    AMZN  5.572200e+10  4.698220e+11  3.336400e+10  1090000000000
# 4      FB  5.205000e+10  1.179290e+11  3.937000e+10   520301000000
# ..    ...           ...           ...           ...            ...
# 93   ISRG  2.140000e+09  5.710000e+09  1.705000e+09    77301000000
# 94    MMC  5.955000e+09  1.980200e+10  3.143000e+09    76517000000
# 95    TGT  1.189000e+10  1.060050e+11  6.946000e+09    74934000000
# 96    ZTS  3.290000e+09  7.776000e+09  2.037000e+09    74764000000
# 97     BA  1.124000e+09  6.228600e+10           NaN    74262000000
#
#         net_debt        assets        equity  cash_equivalents   liabilities
# 0   6.847000e+10  3.506620e+11  6.740506e+10      5.151100e+10  2.832569e+11
# ...

# %%
# могу открыть, посмотреть и редактировать файлы при помощи пандас, но как сделать то же самое при помощи сиквел?

# %%
date.info
# Out:
# <bound method DataFrame.info of    ticker        ebitda         sales    net_profit   market_price  \
# 0    AAPL  1.307950e+11  3.658170e+11  9.468000e+10  2279000000000
# 1    MSFT  9.576900e+10  1.680880e+11  6.127100e+10  1900000000000
# 2    GOOG  9.530500e+10  2.574880e+11  7.603300e+10  1479000000000
# 3    AMZN  5.572200e+10  4.698220e+11  3.336400e+10  1090000000000
# 4      FB  5.205000e+10  1.179290e+11  3.937000e+10   520301000000
# ..    ...           ...           ...           ...            ...
# 93   ISRG  2.140000e+09  5.710000e+09  1.705000e+09    77301000000
# 94    MMC  5.955000e+09  1.980200e+10  3.143000e+09    76517000000
# 95    TGT  1.189000e+10  1.060050e+11  6.946000e+09    74934000000
# 96    ZTS  3.290000e+09  7.776000e+09  2.037000e+09    74764000000
# 97     BA  1.124000e+09  6.228600e+10           NaN    74262000000
#
#         net_debt        assets        equity  cash_equivalents   liabilities
# ...

# %%
date.describe()
# Out:
#              ebitda         sales    net_profit  market_price      net_debt  \
# count  8.800000e+01  9.700000e+01  9.600000e+01  9.800000e+01  9.700000e+01
# mean   1.876440e+10  7.579586e+10  1.156874e+10  2.318694e+11  4.616985e+10
# std    2.099711e+10  9.516701e+10  1.471064e+10  3.301440e+11  1.083598e+11
# min    8.600000e+08  5.710000e+09  2.300000e+08  7.426200e+10 -1.054530e+11
# 25%    8.711750e+09  2.410500e+10  4.274750e+09  9.119575e+10  3.957000e+09
# 50%    1.204400e+10  4.307500e+10  6.506000e+09  1.432595e+11  1.632900e+10
# 75%    1.918300e+10  8.017100e+10  1.320500e+10  2.105095e+11  3.874800e+10
# max    1.307950e+11  5.727540e+11  9.468000e+10  2.279000e+12  5.374110e+11
#
#              assets        equity  cash_equivalents   liabilities
# count  9.700000e+01  9.600000e+01      9.700000e+01  9.600000e+01
# mean   2.642238e+11  5.199309e+10      1.490327e+10  2.148405e+11
# std    6.084057e+11  6.075936e+10      2.317876e+10  5.667565e+11
# ...
